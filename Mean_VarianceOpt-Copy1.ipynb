# %% [markdown]
# # README
# Dear participants,
#
# Your task is to create a trading strategy that maximizes profits and minimizes risks using the training dataset. The training dataset contains daily prices for 12 stocks from 4 sectors. Strategies must be backtested using the zipline platform, the installation and usage of which is demonstrated in this notebook. An example strategy (called a Moving Average crossover strategy) is shown below.
#
# What is a strategy?
# >A strategy is simply an algorithm that takes in price data (Open, High, Low, Close and Volume) and outputs either a buy or sell signal for the current point in time.
#
# What is backtesting?
# >Backtesting is a method used to test a trading strategy using historical data. At each point in time, the algorithm is passed price data upto that point - based on which the algorithm outputs a decision to buy/sell/do nothing. In this way, the performance of a strategy can be estimated based on past data.
#
# What are the most important metrics for evaluation?
# 1. **(Final) Portfolio value** - the higher the better
# 2. **(Average) Sharpe ratio** measures risk-adjusted returns of a returns series. Put simply, it is the expected return divided by the volatility, so the higher it is, the better. An n-period rolling sharpe ratio simply calculates the annualized sharpe ratio for the last n periods. We will be focusing on this rolling 30-day sharpe ratio as the most important metric for evaluation. However, we are interested in both the stability of the rolling sharpe ratio as well as its actual value.
# 3. **(Max) Drawdown** is a measure of the highest amount of money that the strategy loses compared to its previous peak. Plotting drawdowns provides a good picture of the risks associated with a strategy.

# %%
# !pip install zipline-reloaded
# Out:
# Requirement already satisfied: zipline-reloaded in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (2.3)
# Requirement already satisfied: click>=4.0.0 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from zipline-reloaded) (8.1.3)
# Requirement already satisfied: bcolz-zipline>=1.2.6 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from zipline-reloaded) (1.2.6)
# Requirement already satisfied: scipy>=0.17.1 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from zipline-reloaded) (1.9.3)
# Requirement already satisfied: python-dateutil>=2.4.2 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from zipline-reloaded) (2.8.2)
# Requirement already satisfied: lru-dict>=1.1.4 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from zipline-reloaded) (1.1.8)
# Requirement already satisfied: ta-lib>=0.4.09 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from zipline-reloaded) (0.4.19)
# Requirement already satisfied: h5py>=2.7.1 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from zipline-reloaded) (3.7.0)
# Requirement already satisfied: numpy<1.24,>=1.14.5 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from zipline-reloaded) (1.22.3)
# Requirement already satisfied: exchange-calendars<=3.3 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from zipline-reloaded) (3.3)
# Requirement already satisfied: python-interface>=1.5.3 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from zipline-reloaded) (1.6.1)
# Requirement already satisfied: trading-calendars>=1.6.1 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from zipline-reloaded) (2.1.1)
# Requirement already satisfied: intervaltree>=2.1.0 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from zipline-reloaded) (3.1.0)
# Requirement already satisfied: requests>=2.9.1 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from zipline-reloaded) (2.28.1)
# Requirement already satisfied: tables>=3.4.3 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from zipline-reloaded) (3.7.0)
# Requirement already satisfied: pytz>=2018.5 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from zipline-reloaded) (2022.6)
# Requirement already satisfied: logbook>=1.0 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from zipline-reloaded) (1.5.3)
# Requirement already satisfied: sqlalchemy<2,>=1.0.8A in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from zipline-reloaded) (1.4.44)
# Requirement already satisfied: empyrical-reloaded>=0.5.7 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from zipline-reloaded) (0.5.8)
# Requirement already satisfied: numexpr>=2.6.1 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from zipline-reloaded) (2.8.4)
# Requirement already satisfied: bottleneck>=1.0.0 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from zipline-reloaded) (1.3.5)
# Requirement already satisfied: alembic>=0.7.7 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from zipline-reloaded) (1.8.1)
# Requirement already satisfied: iso4217>=1.6.20180829 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from zipline-reloaded) (1.11.20220401)
# Requirement already satisfied: patsy>=0.4.0 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from zipline-reloaded) (0.5.3)
# Requirement already satisfied: multipledispatch>=0.6.0 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from zipline-reloaded) (0.6.0)
# Requirement already satisfied: toolz>=0.8.2 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from zipline-reloaded) (0.12.0)
# Requirement already satisfied: pandas<1.6,>=1.1.0 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from zipline-reloaded) (1.5.2)
# Requirement already satisfied: iso3166>=2.1.1 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from zipline-reloaded) (2.1.1)
# Requirement already satisfied: six>=1.10.0 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from zipline-reloaded) (1.16.0)
# Requirement already satisfied: networkx>=2.0 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from zipline-reloaded) (2.8.8)
# Requirement already satisfied: statsmodels>=0.6.1 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from zipline-reloaded) (0.13.5)
# Requirement already satisfied: Mako in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from alembic>=0.7.7->zipline-reloaded) (1.2.4)
# Requirement already satisfied: yfinance>=0.1.55 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from empyrical-reloaded>=0.5.7->zipline-reloaded) (0.1.87)
# Requirement already satisfied: pandas-datareader>=0.4 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from empyrical-reloaded>=0.5.7->zipline-reloaded) (0.10.0)
# Requirement already satisfied: pyluach in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from exchange-calendars<=3.3->zipline-reloaded) (2.0.2)
# Requirement already satisfied: korean-lunar-calendar in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from exchange-calendars<=3.3->zipline-reloaded) (0.3.1)
# Requirement already satisfied: sortedcontainers<3.0,>=2.0 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from intervaltree>=2.1.0->zipline-reloaded) (2.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from requests>=2.9.1->zipline-reloaded) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from requests>=2.9.1->zipline-reloaded) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from requests>=2.9.1->zipline-reloaded) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from requests>=2.9.1->zipline-reloaded) (3.4)
# Requirement already satisfied: greenlet!=0.4.17 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from sqlalchemy<2,>=1.0.8A->zipline-reloaded) (2.0.1)
# Requirement already satisfied: packaging>=21.3 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from statsmodels>=0.6.1->zipline-reloaded) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from packaging>=21.3->statsmodels>=0.6.1->zipline-reloaded) (3.0.9)
# Requirement already satisfied: lxml in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from pandas-datareader>=0.4->empyrical-reloaded>=0.5.7->zipline-reloaded) (4.9.1)
# Requirement already satisfied: appdirs>=1.4.4 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from yfinance>=0.1.55->empyrical-reloaded>=0.5.7->zipline-reloaded) (1.4.4)
# Requirement already satisfied: multitasking>=0.0.7 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from yfinance>=0.1.55->empyrical-reloaded>=0.5.7->zipline-reloaded) (0.0.11)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from Mako->alembic>=0.7.7->zipline-reloaded) (2.1.1)

# %%
# !pip install PyPortfolioOpt
# !pip install sklearn
# Out:
# Requirement already satisfied: PyPortfolioOpt in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (1.5.4)
# Requirement already satisfied: scipy<2.0,>=1.3 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from PyPortfolioOpt) (1.9.3)
# Requirement already satisfied: pandas>=0.19 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from PyPortfolioOpt) (1.5.2)
# Requirement already satisfied: numpy<2.0.0,>=1.22.4 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from PyPortfolioOpt) (1.23.5)
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.10 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from PyPortfolioOpt) (1.2.2)
# Requirement already satisfied: ecos>=2 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (2.0.10)
# Requirement already satisfied: scs>=1.1.6 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (3.2.2)
# Requirement already satisfied: osqp>=0.4.1 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (0.6.2.post8)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from pandas>=0.19->PyPortfolioOpt) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from pandas>=0.19->PyPortfolioOpt) (2022.6)
# Requirement already satisfied: qdldl in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from osqp>=0.4.1->cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (0.1.5.post2)
# Requirement already satisfied: six>=1.5 in /home/shahin/anaconda3/envs/quant/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=0.19->PyPortfolioOpt) (1.16.0)
# Collecting sklearn
#   Downloading sklearn-0.0.post1.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2936 sha256=0e542cfe3bb3be325c34add1ed573fe538cd317c9f2c6e76b383b2b2cef70379
#   Stored in directory: /home/shahin/.cache/pip/wheels/f8/e0/3d/9d0c2020c44a519b9f02ab4fa6d2a4a996c98d79ab2f569fa1
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0.post1

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# ingesting, registering calender by calling functions from zipline
# %autoreload 2
import calendar
import os
import pandas as pd
from datetime import datetime, timezone
from zipline.data import bundles as bundles_module
from zipline.data.bundles import register, unregister
from zipline.data.bundles.csvdir import csvdir_equities
from zipline.utils.calendar_utils import register_calendar, get_calendar
from zipline.api import (order, 
                         record, 
                         symbol,
                         get_datetime,
                         order_target_percent,
                         order_target_value,
                         set_benchmark,
                         get_open_orders)
from zipline import run_algorithm
from zipline.api import symbol, schedule_function, date_rules, time_rules
from zipline.api import order_target, order_percent, order_target_percent, record, symbol
import matplotlib.pyplot as plt
from utils import *
import stats
import talib as ta
from zipline.finance import commission
import numpy as np 
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt import risk_models
from pypfopt import expected_returns
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.impute import SimpleImputer
from sklearn.neighbors import KNeighborsRegressor

# %% [markdown]
# ## First we will ingest the training dataset

# %%
# %%capture warnings
calendar_name = 'NYSE'
register("stockdata", csvdir_equities(["daily"],'train/'),calendar_name=calendar_name)
bundles_module.ingest("stockdata")
# Out:
#  | ACG: sid 0
#  | BTL: sid 1
#  | CFL: sid 2
#  | DFT: sid 3
#  | FE: sid 4
#  | JZIL: sid 5
#  | KWF: sid 6
#  | LS: sid 7
#  | MUN: sid 8
#  | NAB: sid 9
#  | NIH: sid 10
#  | VME: sid 11

# %% [markdown]
# ### (optional) The data can be loaded and viewed using the dailyBars object
# You may also choose to work with the csv files themselves

# %%
names = "DFT, ACG, LS, CFL, NAB, BTL, KWF, FE, JZIL, MUN, NIH, VME"
stocks = [x for x in names.split(", ")]
bundle = 'stockdata'
start="2003-07-03"
end = "2004-07-06"
db_obj = dailyBars(coins=stocks, bundle=bundle, calendar=get_calendar("NYSE"))

# %%
db_obj.ohlcvData(start, end, value_list=['open', 'close'])
# Out:
#                             open                                            \
#                              DFT    ACG     LS    CFL    NAB    BTL    KWF
# 2003-07-03 00:00:00+00:00  2.797  0.782  0.407  1.420  2.883  1.029  0.593
# 2003-07-07 00:00:00+00:00  2.831  0.787  0.408  1.446  2.873  1.035  0.604
# 2003-07-08 00:00:00+00:00  2.851  0.794  0.401  1.444  2.879  1.043  0.582
# 2003-07-09 00:00:00+00:00  2.874  0.796  0.407  1.457  2.895  1.054  0.515
# 2003-07-10 00:00:00+00:00  2.864  0.795  0.406  1.464  2.907  1.047  0.486
# ...                          ...    ...    ...    ...    ...    ...    ...
# 2004-06-29 00:00:00+00:00  2.897  0.779  0.310  1.706  2.950  0.837  0.339
# 2004-06-30 00:00:00+00:00  2.919  0.795  0.323  1.711  2.999  0.843  0.341
# 2004-07-01 00:00:00+00:00  2.900  0.788  0.318  1.679  2.979  0.837  0.337
# 2004-07-02 00:00:00+00:00  2.826  0.757  0.306  1.640  2.924  0.816  0.340
# 2004-07-06 00:00:00+00:00  2.786  0.735  0.303  1.626  2.894  0.796  0.359
#
#                                                 ...  close                \
#                               FE   JZIL    MUN  ...     LS    CFL    NAB
# 2003-07-03 00:00:00+00:00  2.741  3.418  6.610  ...  0.409  1.439  2.873
# 2003-07-07 00:00:00+00:00  2.737  3.446  6.687  ...  0.407  1.448  2.886
# 2003-07-08 00:00:00+00:00  2.730  3.454  6.688  ...  0.402  1.452  2.896
# 2003-07-09 00:00:00+00:00  2.730  3.506  6.718  ...  0.406  1.460  2.907
# 2003-07-10 00:00:00+00:00  2.745  3.549  6.730  ...  0.407  1.474  2.921
# ...                          ...    ...    ...  ...    ...    ...    ...
# 2004-06-29 00:00:00+00:00  2.278  3.414  6.686  ...  0.313  1.715  3.003
# 2004-06-30 00:00:00+00:00  2.359  3.403  6.783  ...  0.317  1.672  2.994
# 2004-07-01 00:00:00+00:00  2.273  3.371  6.594  ...  0.311  1.652  2.932
# 2004-07-02 00:00:00+00:00  2.195  3.240  6.608  ...  0.308  1.647  2.938
# 2004-07-06 00:00:00+00:00  2.146  3.127  6.566  ...  0.299  1.583  2.879
#
#
#                              BTL    KWF     FE   JZIL    MUN    NIH    VME
# 2003-07-03 00:00:00+00:00  1.031  0.602  2.741  3.442  6.677  8.676  6.776
# 2003-07-07 00:00:00+00:00  1.045  0.603  2.735  3.454  6.707  8.741  6.814
# 2003-07-08 00:00:00+00:00  1.047  0.517  2.726  3.478  6.695  8.714  6.818
# 2003-07-09 00:00:00+00:00  1.043  0.492  2.739  3.550  6.718  8.679  6.814
# 2003-07-10 00:00:00+00:00  1.046  0.472  2.716  3.484  6.748  8.744  6.882
# ...                          ...    ...    ...    ...    ...    ...    ...
# 2004-06-29 00:00:00+00:00  0.844  0.338  2.306  3.404  6.746  7.731  8.001
# 2004-06-30 00:00:00+00:00  0.839  0.339  2.291  3.372  6.590  8.063  7.867
# 2004-07-01 00:00:00+00:00  0.820  0.321  2.210  3.247  6.596  8.103  7.822
# 2004-07-02 00:00:00+00:00  0.810  0.366  2.192  3.189  6.617  7.987  7.759
# 2004-07-06 00:00:00+00:00  0.784  0.361  2.118  3.115  6.485  7.790  7.573
#
# [253 rows x 24 columns]

# %% [markdown]
# # Backtesting
# Backtesting a strategy in zipline involves two functions:
# 1. initialize: which is invoked once at the start of the backtest. It initializes the context object which is available to the algorithm at each step of backtesting.
# The context object can be used to store variables that can be accessed through the backtest.
# 2. handle_data: this is invoked once for every date in the dataset. The rules for the strategy must be referred to within this function. To access the price data, we call the data object.
#
# For more information, visit [zipline documentation](https://zipline.ml4trading.io/beginner-tutorial)

# %%
# %%capture multicap
bundle = 'stockdata'
start="2003-09-13"
end = "2004-07-06"
capital_base = 10000000
calendar = get_calendar('NYSE')
    

def initialize(context):
    bundle_data = bundles.load(bundle)
    sids = bundle_data.asset_finder.sids
    context.assets = bundle_data.asset_finder.retrieve_all(sids)
    context.capital = capital_base
    context.n_asset = len(context.assets)
    context.window = 30
    context.rebalance_period = 15
    context.time = 0
    
    schedule_function(handle_data,
                      date_rules.month_end(),
                      time_rules.market_close())
    #zapi.schedule_function(handle_data, date_rules.week_start())
    
def handle_data(context, data):
    if context.time<context.window:
        context.time += 1
        return
    
    cleaned_weights = []
#     if context.time == 0 or (context.time % context.rebalance_period == 0):
        
    for asset in context.assets:
        if context.time == 0 or (context.time % context.rebalance_period == 0):
            prices = data.history(asset, fields='price',
                                  bar_count=context.window + 1, frequency='1d')
            priceslow = data.history(asset, fields='low',
                                  bar_count=context.window + 1, frequency='1d')
            X_train, X_test, y_train, y_test = train_test_split(prices, priceslow, test_size=.3, random_state=4)
            knn = KNeighborsRegressor(n_neighbors=5)
            knn.fit(X_train, y_train)
            xx=pd.DataFrame([data.current(asset,fields="price")].reshape(1,-1))
#             yy=pd.DataFrame([data.current(asset,fields="low")]);
            knn.predict(xx)

    context.time += 1
                
    
result = run_algorithm(start=pd.Timestamp(start, tz='utc'),
                        end=pd.Timestamp(end, tz='utc'),
                        initialize=initialize,
                        handle_data=handle_data,
                        capital_base=capital_base,
                        trading_calendar=calendar,
                        bundle='stockdata',
                        data_frequency='daily',
                        )
# Starting portfolio value: 10000000.0
# Final portfolio value: 9944705.030094516
# Average sharpe: 2.2397765962458682
# Max drawdown: -0.026536432255494274
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 47
#      42             knn.predict(xx)
#      44     context.time += 1
# ---> 47 result = run_algorithm(start=pd.Timestamp(start, tz='utc'),
#      48                         end=pd.Timestamp(end, tz='utc'),
#      49                         initialize=initialize,
#      50                         handle_data=handle_data,
#      51                         capital_base=capital_base,
#      52                         trading_calendar=calendar,
#      53                         bundle='stockdata',
#      54                         data_frequency='daily',
#      55                         )
#      56 # Starting portfolio value: 10000000.0
#      57 # Final portfolio value: 9944705.030094516
#      58 # Average sharpe: 2.2397765962458682
#      59 # Max drawdown: -0.026536432255494274
#
# File ~/anaconda3/envs/quant/lib/python3.9/site-packages/zipline/utils/run_algo.py:397, in run_algorithm(start, end, initialize, capital_base, handle_data, before_trading_start, analyze, data_frequency, bundle, bundle_timestamp, trading_calendar, metrics_set, benchmark_returns, default_extension, extensions, strict_extensions, environ, custom_loader, blotter)
#     393 load_extensions(default_extension, extensions, strict_extensions, environ)
#     395 benchmark_spec = BenchmarkSpec.from_returns(benchmark_returns)
# --> 397 return _run(
#     398     handle_data=handle_data,
#     399     initialize=initialize,
#     400     before_trading_start=before_trading_start,
#     401     analyze=analyze,
#     402     algofile=None,
#     403     algotext=None,
#     404     defines=(),
#     405     data_frequency=data_frequency,
#     406     capital_base=capital_base,
#     407     bundle=bundle,
#     408     bundle_timestamp=bundle_timestamp,
#     409     start=start,
#     410     end=end,
#     411     output=os.devnull,
#     412     trading_calendar=trading_calendar,
#     413     print_algo=False,
#     414     metrics_set=metrics_set,
#     415     local_namespace=False,
#     416     environ=environ,
#     417     blotter=blotter,
#     418     custom_loader=custom_loader,
#     419     benchmark_spec=benchmark_spec,
#     420 )
#
# File ~/anaconda3/envs/quant/lib/python3.9/site-packages/zipline/utils/run_algo.py:200, in _run(handle_data, initialize, before_trading_start, analyze, algofile, algotext, defines, data_frequency, capital_base, bundle, bundle_timestamp, start, end, output, trading_calendar, print_algo, metrics_set, local_namespace, environ, blotter, custom_loader, benchmark_spec)
#     197         raise _RunAlgoError(str(e))
#     199 try:
# --> 200     perf = TradingAlgorithm(
#     201         namespace=namespace,
#     202         data_portal=data,
#     203         get_pipeline_loader=choose_loader,
#     204         trading_calendar=trading_calendar,
#     205         sim_params=SimulationParameters(
#     206             start_session=start,
#     207             end_session=end,
#     208             trading_calendar=trading_calendar,
#     209             capital_base=capital_base,
#     210             data_frequency=data_frequency,
#     211         ),
#     212         metrics_set=metrics_set,
#     213         blotter=blotter,
#     214         benchmark_returns=benchmark_returns,
#     215         benchmark_sid=benchmark_sid,
#     216         **{
#     217             "initialize": initialize,
#     218             "handle_data": handle_data,
#     219             "before_trading_start": before_trading_start,
#     220             "analyze": analyze,
#     221         }
#     222         if algotext is None
#     223         else {
#     224             "algo_filename": getattr(algofile, "name", "<algorithm>"),
#     225             "script": algotext,
#     226         },
#     227     ).run()
#     228 except NoBenchmark:
#     229     raise _RunAlgoError(
#     230         (
#     231             "No ``benchmark_spec`` was provided, and"
#    (...)
#     239         ),
#     240     )
#
# File ~/anaconda3/envs/quant/lib/python3.9/site-packages/zipline/algorithm.py:623, in TradingAlgorithm.run(self, data_portal)
#     621 try:
#     622     perfs = []
# --> 623     for perf in self.get_generator():
#     624         perfs.append(perf)
#     626     # convert perf dict to pandas dataframe
#
# File ~/anaconda3/envs/quant/lib/python3.9/site-packages/zipline/gens/tradesimulation.py:228, in AlgorithmSimulator.transform(self)
#     226 for dt, action in self.clock:
#     227     if action == BAR:
# --> 228         for capital_change_packet in every_bar(dt):
#     229             yield capital_change_packet
#     230     elif action == SESSION_START:
#
# File ~/anaconda3/envs/quant/lib/python3.9/site-packages/zipline/gens/tradesimulation.py:143, in AlgorithmSimulator.transform.<locals>.every_bar(dt_to_use, current_data, handle_data)
#     140 for commission in new_commissions:
#     141     metrics_tracker.process_commission(commission)
# --> 143 handle_data(algo, current_data, dt_to_use)
#     145 # grab any new orders from the blotter, then clear the list.
#     146 # this includes cancelled orders.
#     147 new_orders = blotter.new_orders
#
# File ~/anaconda3/envs/quant/lib/python3.9/site-packages/zipline/utils/events.py:204, in EventManager.handle_data(self, context, data, dt)
#     202 with self._create_context(data):
#     203     for event in self._events:
# --> 204         event.handle_data(
#     205             context,
#     206             data,
#     207             dt,
#     208         )
#
# File ~/anaconda3/envs/quant/lib/python3.9/site-packages/zipline/utils/events.py:227, in Event.handle_data(self, context, data, dt)
#     223 """
#     224 Calls the callable only when the rule is triggered.
#     225 """
#     226 if self.rule.should_trigger(dt):
# --> 227     self.callback(context, data)
#
# File ~/anaconda3/envs/quant/lib/python3.9/site-packages/zipline/algorithm.py:446, in TradingAlgorithm.handle_data(self, data)
#     444 def handle_data(self, data):
#     445     if self._handle_data:
# --> 446         self._handle_data(self, data)
#
# Cell In[34], line 39, in handle_data(context, data)
#      37             X_train, X_test, y_train, y_test = train_test_split(prices, priceslow, test_size=.3, random_state=4)
#      38             knn = KNeighborsRegressor(n_neighbors=5)
# ---> 39             knn.fit(X_train, y_train)
#      40             xx=pd.DataFrame([data.current(asset,fields="price")].reshape(1,-1))
#      41 #             yy=pd.DataFrame([data.current(asset,fields="low")]);
#
# File ~/anaconda3/envs/quant/lib/python3.9/site-packages/sklearn/neighbors/_regression.py:210, in KNeighborsRegressor.fit(self, X, y)
#     191 """Fit the k-nearest neighbors regressor from the training dataset.
#     192
#     193 Parameters
#    (...)
#     206     The fitted k-nearest neighbors regressor.
#     207 """
#     208 self.weights = _check_weights(self.weights)
# --> 210 return self._fit(X, y)
#
# File ~/anaconda3/envs/quant/lib/python3.9/site-packages/sklearn/neighbors/_base.py:407, in NeighborsBase._fit(self, X, y)
#     405 if self._get_tags()["requires_y"]:
#     406     if not isinstance(X, (KDTree, BallTree, NeighborsBase)):
# --> 407         X, y = self._validate_data(
#     408             X, y, accept_sparse="csr", multi_output=True, order="C"
#     409         )
#     411     if is_classifier(self):
#     412         # Classification targets require a specific format
#     413         if y.ndim == 1 or y.ndim == 2 and y.shape[1] == 1:
#
# File ~/anaconda3/envs/quant/lib/python3.9/site-packages/sklearn/base.py:596, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     594         y = check_array(y, input_name="y", **check_y_params)
#     595     else:
# --> 596         X, y = check_X_y(X, y, **check_params)
#     597     out = X, y
#     599 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/anaconda3/envs/quant/lib/python3.9/site-packages/sklearn/utils/validation.py:1074, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1069         estimator_name = _check_estimator_name(estimator)
#    1070     raise ValueError(
#    1071         f"{estimator_name} requires y to be passed, but the target y is None"
#    1072     )
# -> 1074 X = check_array(
#    1075     X,
#    1076     accept_sparse=accept_sparse,
#    1077     accept_large_sparse=accept_large_sparse,
#    1078     dtype=dtype,
#    1079     order=order,
#    1080     copy=copy,
#    1081     force_all_finite=force_all_finite,
#    1082     ensure_2d=ensure_2d,
#    1083     allow_nd=allow_nd,
#    1084     ensure_min_samples=ensure_min_samples,
#    1085     ensure_min_features=ensure_min_features,
#    1086     estimator=estimator,
#    1087     input_name="X",
#    1088 )
#    1090 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1092 check_consistent_length(X, y)
#
# File ~/anaconda3/envs/quant/lib/python3.9/site-packages/sklearn/utils/validation.py:879, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     877     # If input is 1D raise error
#     878     if array.ndim == 1:
# --> 879         raise ValueError(
#     880             "Expected 2D array, got 1D array instead:\narray={}.\n"
#     881             "Reshape your data either using array.reshape(-1, 1) if "
#     882             "your data has a single feature or array.reshape(1, -1) "
#     883             "if it contains a single sample.".format(array)
#     884         )
#     886 if dtype_numeric and array.dtype.kind in "USV":
#     887     raise ValueError(
#     888         "dtype='numeric' is not compatible with arrays of bytes/strings."
#     889         "Convert your data to numeric values explicitly instead."
#     890     )
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[0.719 0.724 0.712 0.675 0.692 0.718 0.675 0.733 0.69  0.679 0.695 0.664
#  0.716 0.708 0.695 0.685 0.722 0.717 0.704 0.698 0.704].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
result
# Out:
#                                         period_open              period_close  \
# 2003-09-15 20:00:00+00:00 2003-09-15 13:31:00+00:00 2003-09-15 20:00:00+00:00
# 2003-09-16 20:00:00+00:00 2003-09-16 13:31:00+00:00 2003-09-16 20:00:00+00:00
# 2003-09-17 20:00:00+00:00 2003-09-17 13:31:00+00:00 2003-09-17 20:00:00+00:00
# 2003-09-18 20:00:00+00:00 2003-09-18 13:31:00+00:00 2003-09-18 20:00:00+00:00
# 2003-09-19 20:00:00+00:00 2003-09-19 13:31:00+00:00 2003-09-19 20:00:00+00:00
# ...                                             ...                       ...
# 2004-06-29 20:00:00+00:00 2004-06-29 13:31:00+00:00 2004-06-29 20:00:00+00:00
# 2004-06-30 20:00:00+00:00 2004-06-30 13:31:00+00:00 2004-06-30 20:00:00+00:00
# 2004-07-01 20:00:00+00:00 2004-07-01 13:31:00+00:00 2004-07-01 20:00:00+00:00
# 2004-07-02 20:00:00+00:00 2004-07-02 13:31:00+00:00 2004-07-02 20:00:00+00:00
# 2004-07-06 20:00:00+00:00 2004-07-06 13:31:00+00:00 2004-07-06 20:00:00+00:00
#
#                            starting_exposure            pnl  \
# 2003-09-15 20:00:00+00:00       0.000000e+00       0.000000
# 2003-09-16 20:00:00+00:00       0.000000e+00       0.000000
# 2003-09-17 20:00:00+00:00       0.000000e+00       0.000000
# 2003-09-18 20:00:00+00:00       0.000000e+00       0.000000
# 2003-09-19 20:00:00+00:00       0.000000e+00       0.000000
# ...                                      ...            ...
# 2004-06-29 20:00:00+00:00       2.299501e+07  167888.094158
# 2004-06-30 20:00:00+00:00       2.318755e+07 -207311.092930
# 2004-07-01 20:00:00+00:00       2.307674e+07 -655100.780481
# 2004-07-02 20:00:00+00:00       2.244200e+07  -39709.489905
# 2004-07-06 20:00:00+00:00       2.242439e+07 -726183.510846
#
#                                                                 transactions  \
# 2003-09-15 20:00:00+00:00                                                 []
# 2003-09-16 20:00:00+00:00                                                 []
# 2003-09-17 20:00:00+00:00                                                 []
# 2003-09-18 20:00:00+00:00                                                 []
# 2003-09-19 20:00:00+00:00                                                 []
# ...                                                                      ...
# 2004-06-29 20:00:00+00:00  [{'amount': 10580, 'dt': 2004-06-29 20:00:00+0...
# 2004-06-30 20:00:00+00:00  [{'amount': 12538, 'dt': 2004-06-30 20:00:00+0...
# 2004-07-01 20:00:00+00:00  [{'amount': 16026, 'dt': 2004-07-01 20:00:00+0...
# 2004-07-02 20:00:00+00:00  [{'amount': 12951, 'dt': 2004-07-02 20:00:00+0...
# 2004-07-06 20:00:00+00:00  [{'amount': 17897, 'dt': 2004-07-06 20:00:00+0...
#
#                            capital_used  short_exposure  ending_value  \
# 2003-09-15 20:00:00+00:00      0.000000             0.0  0.000000e+00
# 2003-09-16 20:00:00+00:00      0.000000             0.0  0.000000e+00
# 2003-09-17 20:00:00+00:00      0.000000             0.0  0.000000e+00
# 2003-09-18 20:00:00+00:00      0.000000             0.0  0.000000e+00
# 2003-09-19 20:00:00+00:00      0.000000             0.0  0.000000e+00
# ...                                 ...             ...           ...
# 2004-06-29 20:00:00+00:00 -24649.268842             0.0  2.318755e+07
# 2004-06-30 20:00:00+00:00 -96504.232930             0.0  2.307674e+07
# 2004-07-01 20:00:00+00:00 -20365.202480             0.0  2.244200e+07
# 2004-07-02 20:00:00+00:00 -22091.928905             0.0  2.242439e+07
# 2004-07-06 20:00:00+00:00   7606.474155             0.0  2.169060e+07
#
#                            long_exposure  shorts_count  ...  \
# 2003-09-15 20:00:00+00:00   0.000000e+00             0  ...
# 2003-09-16 20:00:00+00:00   0.000000e+00             0  ...
# 2003-09-17 20:00:00+00:00   0.000000e+00             0  ...
# 2003-09-18 20:00:00+00:00   0.000000e+00             0  ...
# 2003-09-19 20:00:00+00:00   0.000000e+00             0  ...
# ...                                  ...           ...  ...
# 2004-06-29 20:00:00+00:00   2.318755e+07             0  ...
# 2004-06-30 20:00:00+00:00   2.307674e+07             0  ...
# 2004-07-01 20:00:00+00:00   2.244200e+07             0  ...
# 2004-07-02 20:00:00+00:00   2.242439e+07             0  ...
# 2004-07-06 20:00:00+00:00   2.169060e+07             0  ...
#
#                            benchmark_volatility  excess_return  period_label  \
# 2003-09-15 20:00:00+00:00                   NaN            0.0       2003-09
# 2003-09-16 20:00:00+00:00                   0.0            0.0       2003-09
# 2003-09-17 20:00:00+00:00                   0.0            0.0       2003-09
# 2003-09-18 20:00:00+00:00                   0.0            0.0       2003-09
# 2003-09-19 20:00:00+00:00                   0.0            0.0       2003-09
# ...                                         ...            ...           ...
# 2004-06-29 20:00:00+00:00                   0.0            0.0       2004-06
# 2004-06-30 20:00:00+00:00                   0.0            0.0       2004-06
# 2004-07-01 20:00:00+00:00                   0.0            0.0       2004-07
# 2004-07-02 20:00:00+00:00                   0.0            0.0       2004-07
# 2004-07-06 20:00:00+00:00                   0.0            0.0       2004-07
#
#                           alpha  beta  algorithm_period_return  max_drawdown  \
# 2003-09-15 20:00:00+00:00  None  None                 0.000000       0.00000
# 2003-09-16 20:00:00+00:00  None  None                 0.000000       0.00000
# 2003-09-17 20:00:00+00:00  None  None                 0.000000       0.00000
# 2003-09-18 20:00:00+00:00  None  None                 0.000000       0.00000
# 2003-09-19 20:00:00+00:00  None  None                 0.000000       0.00000
# ...                         ...   ...                      ...           ...
# 2004-06-29 20:00:00+00:00  None  None                 0.127415      -0.19491
# 2004-06-30 20:00:00+00:00  None  None                 0.106684      -0.19491
# 2004-07-01 20:00:00+00:00  None  None                 0.041174      -0.19491
# 2004-07-02 20:00:00+00:00  None  None                 0.037203      -0.19491
# 2004-07-06 20:00:00+00:00  None  None                -0.035415      -0.19491
#
#                              sharpe  treasury_period_return   sortino
# 2003-09-15 20:00:00+00:00       NaN                     0.0       NaN
# 2003-09-16 20:00:00+00:00       NaN                     0.0       NaN
# 2003-09-17 20:00:00+00:00       NaN                     0.0       NaN
# 2003-09-18 20:00:00+00:00       NaN                     0.0       NaN
# 2003-09-19 20:00:00+00:00       NaN                     0.0       NaN
# ...                             ...                     ...       ...
# 2004-06-29 20:00:00+00:00  0.772708                     0.0  1.234595
# 2004-06-30 20:00:00+00:00  0.667102                     0.0  1.059624
# 2004-07-01 20:00:00+00:00  0.329544                     0.0  0.495773
# 2004-07-02 20:00:00+00:00  0.308786                     0.0  0.464458
# 2004-07-06 20:00:00+00:00 -0.053302                     0.0 -0.075726
#
# [203 rows x 37 columns]

# %%
stats.show_rolling_stats(result, 30)
# Out:
# Starting portfolio value: 10000000.0
# Final portfolio value: 9645845.281335037
# Average sharpe: 0.174113926165314
# Max drawdown: -0.1949100328326896
#                                         period_open              period_close  \
# 2003-09-15 20:00:00+00:00 2003-09-15 13:31:00+00:00 2003-09-15 20:00:00+00:00
# 2003-09-16 20:00:00+00:00 2003-09-16 13:31:00+00:00 2003-09-16 20:00:00+00:00
# 2003-09-17 20:00:00+00:00 2003-09-17 13:31:00+00:00 2003-09-17 20:00:00+00:00
# 2003-09-18 20:00:00+00:00 2003-09-18 13:31:00+00:00 2003-09-18 20:00:00+00:00
# 2003-09-19 20:00:00+00:00 2003-09-19 13:31:00+00:00 2003-09-19 20:00:00+00:00
# ...                                             ...                       ...
# 2004-06-29 20:00:00+00:00 2004-06-29 13:31:00+00:00 2004-06-29 20:00:00+00:00
# 2004-06-30 20:00:00+00:00 2004-06-30 13:31:00+00:00 2004-06-30 20:00:00+00:00
# 2004-07-01 20:00:00+00:00 2004-07-01 13:31:00+00:00 2004-07-01 20:00:00+00:00
# 2004-07-02 20:00:00+00:00 2004-07-02 13:31:00+00:00 2004-07-02 20:00:00+00:00
# 2004-07-06 20:00:00+00:00 2004-07-06 13:31:00+00:00 2004-07-06 20:00:00+00:00
#
#                            starting_exposure            pnl  \
# 2003-09-15 20:00:00+00:00       0.000000e+00       0.000000
# 2003-09-16 20:00:00+00:00       0.000000e+00       0.000000
# 2003-09-17 20:00:00+00:00       0.000000e+00       0.000000
# 2003-09-18 20:00:00+00:00       0.000000e+00       0.000000
# 2003-09-19 20:00:00+00:00       0.000000e+00       0.000000
# ...                                      ...            ...
# 2004-06-29 20:00:00+00:00       2.299501e+07  167888.094158
# 2004-06-30 20:00:00+00:00       2.318755e+07 -207311.092930
# 2004-07-01 20:00:00+00:00       2.307674e+07 -655100.780481
# 2004-07-02 20:00:00+00:00       2.244200e+07  -39709.489905
# 2004-07-06 20:00:00+00:00       2.242439e+07 -726183.510846
#
#                                                                 transactions  \
# 2003-09-15 20:00:00+00:00                                                 []
# 2003-09-16 20:00:00+00:00                                                 []
# 2003-09-17 20:00:00+00:00                                                 []
# 2003-09-18 20:00:00+00:00                                                 []
# 2003-09-19 20:00:00+00:00                                                 []
# ...                                                                      ...
# 2004-06-29 20:00:00+00:00  [{'amount': 10580, 'dt': 2004-06-29 20:00:00+0...
# 2004-06-30 20:00:00+00:00  [{'amount': 12538, 'dt': 2004-06-30 20:00:00+0...
# 2004-07-01 20:00:00+00:00  [{'amount': 16026, 'dt': 2004-07-01 20:00:00+0...
# 2004-07-02 20:00:00+00:00  [{'amount': 12951, 'dt': 2004-07-02 20:00:00+0...
# 2004-07-06 20:00:00+00:00  [{'amount': 17897, 'dt': 2004-07-06 20:00:00+0...
#
#                            capital_used  short_exposure  ending_value  \
# 2003-09-15 20:00:00+00:00      0.000000             0.0  0.000000e+00
# 2003-09-16 20:00:00+00:00      0.000000             0.0  0.000000e+00
# 2003-09-17 20:00:00+00:00      0.000000             0.0  0.000000e+00
# 2003-09-18 20:00:00+00:00      0.000000             0.0  0.000000e+00
# 2003-09-19 20:00:00+00:00      0.000000             0.0  0.000000e+00
# ...                                 ...             ...           ...
# 2004-06-29 20:00:00+00:00 -24649.268842             0.0  2.318755e+07
# 2004-06-30 20:00:00+00:00 -96504.232930             0.0  2.307674e+07
# 2004-07-01 20:00:00+00:00 -20365.202480             0.0  2.244200e+07
# 2004-07-02 20:00:00+00:00 -22091.928905             0.0  2.242439e+07
# 2004-07-06 20:00:00+00:00   7606.474155             0.0  2.169060e+07
#
#                            long_exposure  shorts_count  ...  alpha  beta  \
# 2003-09-15 20:00:00+00:00   0.000000e+00             0  ...   None  None
# 2003-09-16 20:00:00+00:00   0.000000e+00             0  ...   None  None
# 2003-09-17 20:00:00+00:00   0.000000e+00             0  ...   None  None
# 2003-09-18 20:00:00+00:00   0.000000e+00             0  ...   None  None
# 2003-09-19 20:00:00+00:00   0.000000e+00             0  ...   None  None
# ...                                  ...           ...  ...    ...   ...
# 2004-06-29 20:00:00+00:00   2.318755e+07             0  ...   None  None
# 2004-06-30 20:00:00+00:00   2.307674e+07             0  ...   None  None
# 2004-07-01 20:00:00+00:00   2.244200e+07             0  ...   None  None
# 2004-07-02 20:00:00+00:00   2.242439e+07             0  ...   None  None
# 2004-07-06 20:00:00+00:00   2.169060e+07             0  ...   None  None
#
#                            algorithm_period_return max_drawdown    sharpe  \
# 2003-09-15 20:00:00+00:00                 0.000000      0.00000       NaN
# 2003-09-16 20:00:00+00:00                 0.000000      0.00000       NaN
# 2003-09-17 20:00:00+00:00                 0.000000      0.00000       NaN
# 2003-09-18 20:00:00+00:00                 0.000000      0.00000       NaN
# 2003-09-19 20:00:00+00:00                 0.000000      0.00000       NaN
# ...                                            ...          ...       ...
# 2004-06-29 20:00:00+00:00                 0.127415     -0.19491  0.772708
# 2004-06-30 20:00:00+00:00                 0.106684     -0.19491  0.667102
# 2004-07-01 20:00:00+00:00                 0.041174     -0.19491  0.329544
# 2004-07-02 20:00:00+00:00                 0.037203     -0.19491  0.308786
# 2004-07-06 20:00:00+00:00                -0.035415     -0.19491 -0.053302
#
#                            treasury_period_return   sortino  rolling_sharpe  \
# 2003-09-15 20:00:00+00:00                     0.0       NaN             NaN
# 2003-09-16 20:00:00+00:00                     0.0       NaN             NaN
# 2003-09-17 20:00:00+00:00                     0.0       NaN             NaN
# 2003-09-18 20:00:00+00:00                     0.0       NaN             NaN
# 2003-09-19 20:00:00+00:00                     0.0       NaN             NaN
# ...                                           ...       ...             ...
# 2004-06-29 20:00:00+00:00                     0.0  1.234595        3.530946
# 2004-06-30 20:00:00+00:00                     0.0  1.059624        2.063166
# 2004-07-01 20:00:00+00:00                     0.0  0.495773        0.537260
# 2004-07-02 20:00:00+00:00                     0.0  0.464458        0.178987
# 2004-07-06 20:00:00+00:00                     0.0 -0.075726       -1.006712
#
#                            rolling_vol  drawdowns
# 2003-09-15 20:00:00+00:00          NaN        NaN
# 2003-09-16 20:00:00+00:00          NaN   0.000000
# 2003-09-17 20:00:00+00:00          NaN   0.000000
# 2003-09-18 20:00:00+00:00          NaN   0.000000
# 2003-09-19 20:00:00+00:00          NaN   0.000000
# ...                                ...        ...
# 2004-06-29 20:00:00+00:00     0.021014  -0.010779
# 2004-06-30 20:00:00+00:00     0.020088  -0.028969
# 2004-07-01 20:00:00+00:00     0.023025  -0.086449
# 2004-07-02 20:00:00+00:00     0.022943  -0.089933
# 2004-07-06 20:00:00+00:00     0.026217  -0.153650
#
# [203 rows x 40 columns]

# %% [markdown]
# ### And that's all. Please reach out on the [slack channel](https://join.slack.com/share/enQtNDQzNDkyNDY4OTIwNS02MmU1YjY4MTI2YjAxZmIwYTI1ZjcyYjEzOGFkODc4MGE0YTJmMWU4ZTU2OGRhZmJkNWFiZDkwOGI4YmJhOTk4) if you have any queries, questions or even suggestions. Happy coding!
